# %% [markdown]
# # Eis a calamitosa situação previdenciária dos estados brasileiros

# %% [markdown]
# ## Objetivos
#
# * Fazer um analises da situação Previdenciaria dos Estados Brasileros.
# * Utilizar a ferramenta de python pandas para a transformação e analises dos dados.
# * Ler arquivos de excel com pandas.
# * fazer plots de graficos com pandas.

# %%
import pandas as pd

# %%
pd.ExcelFile
# Out:
# pandas.io.excel._base.ExcelFile

# %%
excel_file= pd.ExcelFile('Input/Financas_Estaduais.xlsx')

# %%
dir(excel_file)
# Out:
# ['_ODFReader',
#  '_OpenpyxlReader',
#  '_XlrdReader',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__fspath__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_engines',
#  '_io',
#  '_reader',
#  'book',
#  'close',
#  'engine',
#  'io',
#  'parse',
#  'sheet_names']

# %%
excel_file.sheet_names
# Out:
# ['Info',
#  'TOTAL',
#  'Demografia_Estadual',
#  'RJ',
#  'SP',
#  'MG',
#  'ES',
#  'RS',
#  'SC',
#  'PR',
#  'MS',
#  'MT',
#  'GO',
#  'DF',
#  'TO',
#  'PA',
#  'AP',
#  'RR',
#  'RO',
#  'AM',
#  'AC',
#  'BA',
#  'RN',
#  'AL',
#  'PB',
#  'CE',
#  'PE',
#  'PI',
#  'MA',
#  'SE',
#  'DTP',
#  'Endividamento']

# %%
sheet_names_per_state=[sheet_name for sheet_name in excel_file.sheet_names if len(sheet_name)==2 ]
sheet_names_per_state
# Out:
# ['RJ',
#  'SP',
#  'MG',
#  'ES',
#  'RS',
#  'SC',
#  'PR',
#  'MS',
#  'MT',
#  'GO',
#  'DF',
#  'TO',
#  'PA',
#  'AP',
#  'RR',
#  'RO',
#  'AM',
#  'AC',
#  'BA',
#  'RN',
#  'AL',
#  'PB',
#  'CE',
#  'PE',
#  'PI',
#  'MA',
#  'SE']

# %%
df_RJ=excel_file.parse(
    sheet_names_per_state[0],
    usecols='B:M')
df_RJ.T
# Out:
#                                                   0               1   \
# Unnamed: 1   Unidade: R$ milhões, a preços correntes  Rio de Janeiro
# Unnamed: 2                                       NaN            2008
# Unnamed: 3                                       NaN            2009
# Unnamed: 4                                       NaN            2010
# Unnamed: 5                                       NaN            2011
# Unnamed: 6                                       NaN            2012
# Unnamed: 7                                       NaN            2013
# Unnamed: 8                                       NaN            2014
# Unnamed: 9                                       NaN            2015
# Unnamed: 10                                      NaN            2016
# Unnamed: 11                                      NaN            2017
# Unnamed: 12                                      NaN         2018/08
#
#                         2                 3           4        5        6   \
# Unnamed: 1   Receita Bruta  Receita Corrente  Tributária     ICMS     IPVA
# Unnamed: 2         41300.2           41047.3     22920.7      NaN      NaN
# Unnamed: 3         39727.4           39100.5     24884.7      NaN      NaN
# Unnamed: 4           47316           46563.9     29086.6      NaN      NaN
# Unnamed: 5           53416           52464.1     32555.7      NaN      NaN
# Unnamed: 6           55583           55059.7     35141.7      NaN      NaN
# Unnamed: 7         58526.2           58046.8     35685.9      NaN      NaN
# Unnamed: 8         58046.9           57708.9     37403.2      NaN      NaN
# Unnamed: 9         50971.1           50590.5     29071.7  19189.9  919.719
# Unnamed: 10        45766.7           45708.4     30547.8  18659.9  1121.33
# Unnamed: 11        52628.2           51930.6       32380  19327.8  1142.64
# Unnamed: 12        41576.9           39669.3       23932  17780.7  1130.25
#
#                   7        8        9   ...                            41  \
# Unnamed: 1      ITCD     IRRF   Outras  ...  d/q Aposentadorias/ Inativos
# Unnamed: 2       NaN      NaN      NaN  ...                             -
# Unnamed: 3       NaN      NaN      NaN  ...                             -
# Unnamed: 4       NaN      NaN      NaN  ...                             -
# Unnamed: 5       NaN      NaN      NaN  ...                             -
# Unnamed: 6       NaN      NaN      NaN  ...                             -
# Unnamed: 7       NaN      NaN      NaN  ...                             -
# Unnamed: 8       NaN      NaN      NaN  ...                             -
# Unnamed: 9   679.925  2988.13  5294.06  ...                       52.9519
# Unnamed: 10  1112.53  3173.28  6480.76  ...                       47.7271
# Unnamed: 11  959.647  3831.32  7118.64  ...                       36.8444
# Unnamed: 12  609.014  2412.22  1999.76  ...                        39.454
#
#                                  42                     43  \
# Unnamed: 1   d/q Reformas/ Inativos  d/q Pensões/ Inativos
# Unnamed: 2                        -                      -
# Unnamed: 3                        -                      -
# Unnamed: 4                        -                      -
# Unnamed: 5                        -                      -
# Unnamed: 6                        -                      -
# Unnamed: 7                        -                      -
# Unnamed: 8                        -                      -
# Unnamed: 9                  20.0966                22.1978
# Unnamed: 10                 19.5758                20.3363
# Unnamed: 11                 18.0316                17.2545
# Unnamed: 12                 20.5969                18.9216
#
#                                44               45                 46  \
# Unnamed: 1   d/q Demais/ Inativos  Civil/ Inativos  Militar/ Inativos
# Unnamed: 2                      -                -                  -
# Unnamed: 3                      -                -                  -
# Unnamed: 4                      -                -                  -
# Unnamed: 5                      -                -                  -
# Unnamed: 6                      -                -                  -
# Unnamed: 7                      -                -                  -
# Unnamed: 8                      -                -                  -
# Unnamed: 9                4.75372          72.3723             22.874
# Unnamed: 10               12.3608          65.0733            22.5659
# Unnamed: 11               27.8695          50.2757            21.8548
# Unnamed: 12               21.0275           55.427            23.5454
#
#                                                             47  \
# Unnamed: 1   Resultado Previdenciário (R$ milhões, a preços...
# Unnamed: 2                                                 NaN
# Unnamed: 3                                                 NaN
# Unnamed: 4                                                 NaN
# Unnamed: 5                                                 NaN
# Unnamed: 6                                                 NaN
# Unnamed: 7                                                 NaN
# Unnamed: 8                                                 NaN
# Unnamed: 9                                            -878.058
# Unnamed: 10                                             -11346
# Unnamed: 11                                           -10714.6
# Unnamed: 12                                           -749.151
#
#                                                         48  \
# Unnamed: 1   Déficit Previdenciário/ Rec. Corrente Própria
# Unnamed: 2                                               0
# Unnamed: 3                                               0
# Unnamed: 4                                               0
# Unnamed: 5                                               0
# Unnamed: 6                                               0
# Unnamed: 7                                               0
# Unnamed: 8                                               0
# Unnamed: 9                                        -1.94246
# Unnamed: 10                                       -30.7943
# Unnamed: 11                                       -23.2043
# Unnamed: 12                                       -2.09959
#
#                                                     49  \
# Unnamed: 1   Despesa de Capital/ Rec. Corrente Própria
# Unnamed: 2                                     4.76098
# Unnamed: 3                                     7.86034
# Unnamed: 4                                     12.3975
# Unnamed: 5                                     10.5043
# Unnamed: 6                                     11.0806
# Unnamed: 7                                     13.1004
# Unnamed: 8                                     14.7828
# Unnamed: 9                                     14.6469
# Unnamed: 10                                    6.85651
# Unnamed: 11                                    2.16844
# Unnamed: 12                                    1.22081
#
#                                                     50
# Unnamed: 1   Resultado Primário/ Rec. Corrente Própria
# Unnamed: 2                                     8.78422
# Unnamed: 3                                  -0.0888004
# Unnamed: 4                                   -0.319216
# Unnamed: 5                                     2.01315
# Unnamed: 6                                    -5.40473
# Unnamed: 7                                    -12.1995
# Unnamed: 8                                    -17.9581
# Unnamed: 9                                    -8.02499
# Unnamed: 10                                   -16.1946
# Unnamed: 11                                   -12.9183
# Unnamed: 12                                    21.2483
#
# [12 rows x 51 columns]

# %%
df_RJ=df_RJ.T
df_RJ
# Out:
#                                                   0               1   \
# Unnamed: 1   Unidade: R$ milhões, a preços correntes  Rio de Janeiro
# Unnamed: 2                                       NaN            2008
# Unnamed: 3                                       NaN            2009
# Unnamed: 4                                       NaN            2010
# Unnamed: 5                                       NaN            2011
# Unnamed: 6                                       NaN            2012
# Unnamed: 7                                       NaN            2013
# Unnamed: 8                                       NaN            2014
# Unnamed: 9                                       NaN            2015
# Unnamed: 10                                      NaN            2016
# Unnamed: 11                                      NaN            2017
# Unnamed: 12                                      NaN         2018/08
#
#                         2                 3           4        5        6   \
# Unnamed: 1   Receita Bruta  Receita Corrente  Tributária     ICMS     IPVA
# Unnamed: 2         41300.2           41047.3     22920.7      NaN      NaN
# Unnamed: 3         39727.4           39100.5     24884.7      NaN      NaN
# Unnamed: 4           47316           46563.9     29086.6      NaN      NaN
# Unnamed: 5           53416           52464.1     32555.7      NaN      NaN
# Unnamed: 6           55583           55059.7     35141.7      NaN      NaN
# Unnamed: 7         58526.2           58046.8     35685.9      NaN      NaN
# Unnamed: 8         58046.9           57708.9     37403.2      NaN      NaN
# Unnamed: 9         50971.1           50590.5     29071.7  19189.9  919.719
# Unnamed: 10        45766.7           45708.4     30547.8  18659.9  1121.33
# Unnamed: 11        52628.2           51930.6       32380  19327.8  1142.64
# Unnamed: 12        41576.9           39669.3       23932  17780.7  1130.25
#
#                   7        8        9   ...                            41  \
# Unnamed: 1      ITCD     IRRF   Outras  ...  d/q Aposentadorias/ Inativos
# Unnamed: 2       NaN      NaN      NaN  ...                             -
# Unnamed: 3       NaN      NaN      NaN  ...                             -
# Unnamed: 4       NaN      NaN      NaN  ...                             -
# Unnamed: 5       NaN      NaN      NaN  ...                             -
# Unnamed: 6       NaN      NaN      NaN  ...                             -
# Unnamed: 7       NaN      NaN      NaN  ...                             -
# Unnamed: 8       NaN      NaN      NaN  ...                             -
# Unnamed: 9   679.925  2988.13  5294.06  ...                       52.9519
# Unnamed: 10  1112.53  3173.28  6480.76  ...                       47.7271
# Unnamed: 11  959.647  3831.32  7118.64  ...                       36.8444
# Unnamed: 12  609.014  2412.22  1999.76  ...                        39.454
#
#                                  42                     43  \
# Unnamed: 1   d/q Reformas/ Inativos  d/q Pensões/ Inativos
# Unnamed: 2                        -                      -
# Unnamed: 3                        -                      -
# Unnamed: 4                        -                      -
# Unnamed: 5                        -                      -
# Unnamed: 6                        -                      -
# Unnamed: 7                        -                      -
# Unnamed: 8                        -                      -
# Unnamed: 9                  20.0966                22.1978
# Unnamed: 10                 19.5758                20.3363
# Unnamed: 11                 18.0316                17.2545
# Unnamed: 12                 20.5969                18.9216
#
#                                44               45                 46  \
# Unnamed: 1   d/q Demais/ Inativos  Civil/ Inativos  Militar/ Inativos
# Unnamed: 2                      -                -                  -
# Unnamed: 3                      -                -                  -
# Unnamed: 4                      -                -                  -
# Unnamed: 5                      -                -                  -
# Unnamed: 6                      -                -                  -
# Unnamed: 7                      -                -                  -
# Unnamed: 8                      -                -                  -
# Unnamed: 9                4.75372          72.3723             22.874
# Unnamed: 10               12.3608          65.0733            22.5659
# Unnamed: 11               27.8695          50.2757            21.8548
# Unnamed: 12               21.0275           55.427            23.5454
#
#                                                             47  \
# Unnamed: 1   Resultado Previdenciário (R$ milhões, a preços...
# Unnamed: 2                                                 NaN
# Unnamed: 3                                                 NaN
# Unnamed: 4                                                 NaN
# Unnamed: 5                                                 NaN
# Unnamed: 6                                                 NaN
# Unnamed: 7                                                 NaN
# Unnamed: 8                                                 NaN
# Unnamed: 9                                            -878.058
# Unnamed: 10                                             -11346
# Unnamed: 11                                           -10714.6
# Unnamed: 12                                           -749.151
#
#                                                         48  \
# Unnamed: 1   Déficit Previdenciário/ Rec. Corrente Própria
# Unnamed: 2                                               0
# Unnamed: 3                                               0
# Unnamed: 4                                               0
# Unnamed: 5                                               0
# Unnamed: 6                                               0
# Unnamed: 7                                               0
# Unnamed: 8                                               0
# Unnamed: 9                                        -1.94246
# Unnamed: 10                                       -30.7943
# Unnamed: 11                                       -23.2043
# Unnamed: 12                                       -2.09959
#
#                                                     49  \
# Unnamed: 1   Despesa de Capital/ Rec. Corrente Própria
# Unnamed: 2                                     4.76098
# Unnamed: 3                                     7.86034
# Unnamed: 4                                     12.3975
# Unnamed: 5                                     10.5043
# Unnamed: 6                                     11.0806
# Unnamed: 7                                     13.1004
# Unnamed: 8                                     14.7828
# Unnamed: 9                                     14.6469
# Unnamed: 10                                    6.85651
# Unnamed: 11                                    2.16844
# Unnamed: 12                                    1.22081
#
#                                                     50
# Unnamed: 1   Resultado Primário/ Rec. Corrente Própria
# Unnamed: 2                                     8.78422
# Unnamed: 3                                  -0.0888004
# Unnamed: 4                                   -0.319216
# Unnamed: 5                                     2.01315
# Unnamed: 6                                    -5.40473
# Unnamed: 7                                    -12.1995
# Unnamed: 8                                    -17.9581
# Unnamed: 9                                    -8.02499
# Unnamed: 10                                   -16.1946
# Unnamed: 11                                   -12.9183
# Unnamed: 12                                    21.2483
#
# [12 rows x 51 columns]

# %%
df_RJ.reset_index(inplace=True,drop=True)

# %%
df_RJ=df_RJ.drop(labels=[0],axis=1)

# %%
df_RJ.columns=df_RJ.iloc[0]
df_RJ=df_RJ.drop(labels=[0],axis=0)
df_RJ=df_RJ.dropna(axis=1,how='all')

# %%
names=df_RJ.columns.to_list()
names[0]='Ano'
names[names.index('Despesa Total¹')] = 'Despesa Total'
df_RJ.columns=names

# %%
df_RJ['estado']='RJ'

# %%
def get_financials_of_state_from_excel(excel,state):
    df=excel_file.parse(state,usecols='B:M')
    df=df.T
    df.reset_index(inplace=True,drop=True)
    df=df.drop(labels=[0],axis=1)
    df.columns=df.iloc[0]
    df=df.drop(labels=[0],axis=0)
    df=df.dropna(axis=1,how='all')
    names=df.columns.to_list()
    names[0]='Ano'
    names[names.index('Despesa Total¹')] = 'Despesa Total'
    df.columns=names
    df['estado']=state
    return df

df_RJ=get_financials_of_state_from_excel(excel_file,'MS')
df_RJ.T
# Out:
#                                                          1        2        3   \
# Ano                                                    2008     2009     2010
# Receita Bruta                                       6397.51  6433.24  7101.53
# Receita Corrente                                    6170.63  6219.22   6709.1
# Tributária                                          4047.17  3991.13  4380.04
# ICMS                                                    NaN      NaN      NaN
# IPVA                                                    NaN      NaN      NaN
# ITCD                                                    NaN      NaN      NaN
# IRRF                                                    NaN      NaN      NaN
# Outras                                                  NaN      NaN      NaN
# Transferências                                      1495.62  1612.48   1666.5
# FPE                                                     NaN      NaN      NaN
# Outras (inclusive Fundeb)                               NaN      NaN      NaN
# Demais Correntes                                    627.835  615.606  662.556
# Receita de Capital                                  226.885  214.024  392.431
# Despesa Total                                        5327.3  5919.93  6845.96
# Despesa Corrente                                    4918.89  5458.31  6023.63
# Pessoal e Encargos                                  1877.17  2100.97  2424.01
# Ativos                                                  NaN      NaN      NaN
# Inativos                                                NaN      NaN      NaN
# d/q Aposentadorias                                      NaN      NaN      NaN
# d/q Reformas                                            NaN      NaN      NaN
# d/q Pensões                                             NaN      NaN      NaN
# d/q Demais                                              NaN      NaN      NaN
# Civil                                                   NaN      NaN      NaN
# Militar                                                 NaN      NaN      NaN
# Outras Despesas Correntes                           2861.06  3174.67  3435.17
# Transf. Constitucionais e Legais                    1155.47  1121.92  1258.99
# Demais Despesas Correntes                           1705.59  2052.75  2176.18
# Despesa de Capital                                  408.411  461.624  822.328
# Investimentos                                       394.743  429.837   811.83
# Inversões Financeiras                               13.6679  31.7865   10.498
# Resultado Primário                                  1070.21   513.31  255.571
# Receita Corrente Própria/ Receita Bruta             73.0754  71.6083  71.0072
# Receita de Transferências/ Receita Bruta            23.3782  25.0648  23.4668
# Receita de Capital/ Receita Bruta                   3.54646  3.32685  5.52601
# Pessoal/ Despesa Total                              35.2368  35.4897  35.4078
# Pessoal/ Despesa Total ex-Transf.                   44.9963  43.7883  43.3867
# Ativo/ Pessoal e Encargos                                 0        0        0
# Inativo/ Pessoal e Encargos                               0        0        0
# d/q Aposentadorias/ Inativos                              -        -        -
# d/q Reformas/ Inativos                                    -        -        -
# d/q Pensões/ Inativos                                     -        -        -
# d/q Demais/ Inativos                                      -        -        -
# Civil/ Inativos                                           -        -        -
# Militar/ Inativos                                         -        -        -
# Resultado Previdenciário (R$ milhões, a preços ...      NaN      NaN      NaN
# Déficit Previdenciário/ Rec. Corrente Própria             0        0        0
# Despesa de Capital/ Rec. Corrente Própria           8.73605  10.0206  16.3076
# Resultado Primário/ Rec. Corrente Própria           22.8922  11.1426  5.06824
# estado                                                   MS       MS       MS
#
#                                                          4        5        6   \
# Ano                                                    2011     2012     2013
# Receita Bruta                                       8186.59  8920.38  9846.14
# Receita Corrente                                    7738.63  8480.44  9278.83
# Tributária                                          5107.17  5514.05  6174.53
# ICMS                                                    NaN      NaN      NaN
# IPVA                                                    NaN      NaN      NaN
# ITCD                                                    NaN      NaN      NaN
# IRRF                                                    NaN      NaN      NaN
# Outras                                                  NaN      NaN      NaN
# Transferências                                      1878.75  2124.66  2100.35
# FPE                                                     NaN      NaN      NaN
# Outras (inclusive Fundeb)                               NaN      NaN      NaN
# Demais Correntes                                    752.719   841.73  1003.95
# Receita de Capital                                  447.962  439.936  567.315
# Despesa Total                                        7812.2  8322.43  9480.23
# Despesa Corrente                                     6830.5  7544.54  8436.56
# Pessoal e Encargos                                  2693.44  4241.38  4662.34
# Ativos                                                  NaN      NaN      NaN
# Inativos                                                NaN      NaN      NaN
# d/q Aposentadorias                                      NaN      NaN      NaN
# d/q Reformas                                            NaN      NaN      NaN
# d/q Pensões                                             NaN      NaN      NaN
# d/q Demais                                              NaN      NaN      NaN
# Civil                                                   NaN      NaN      NaN
# Militar                                                 NaN      NaN      NaN
# Outras Despesas Correntes                           3946.71  3088.52  3561.36
# Transf. Constitucionais e Legais                    1477.78  1593.92  1786.83
# Demais Despesas Correntes                           2468.93   1494.6  1774.53
# Despesa de Capital                                  981.696  777.886  1043.67
# Investimentos                                       979.755  765.881  1042.29
# Inversões Financeiras                               1.94151  12.0046  1.37121
# Resultado Primário                                  374.394   597.95   365.91
# Receita Corrente Própria/ Receita Bruta              71.579  71.2502  72.9065
# Receita de Transferências/ Receita Bruta            22.9491   23.818  21.3317
# Receita de Capital/ Receita Bruta                    5.4719  4.93181   5.7618
# Pessoal/ Despesa Total                              34.4774  50.9633  49.1796
# Pessoal/ Despesa Total ex-Transf.                   42.5207   63.036  60.6018
# Ativo/ Pessoal e Encargos                                 0        0        0
# Inativo/ Pessoal e Encargos                               0        0        0
# d/q Aposentadorias/ Inativos                              -        -        -
# d/q Reformas/ Inativos                                    -        -        -
# d/q Pensões/ Inativos                                     -        -        -
# d/q Demais/ Inativos                                      -        -        -
# Civil/ Inativos                                           -        -        -
# Militar/ Inativos                                         -        -        -
# Resultado Previdenciário (R$ milhões, a preços ...      NaN      NaN      NaN
# Déficit Previdenciário/ Rec. Corrente Própria             0        0        0
# Despesa de Capital/ Rec. Corrente Própria           16.7528   12.239  14.5388
# Resultado Primário/ Rec. Corrente Própria           6.38911  9.40797  5.09733
# estado                                                   MS       MS       MS
#
#                                                           7           8   \
# Ano                                                     2014        2015
# Receita Bruta                                        10965.2     14504.2
# Receita Corrente                                     10388.5     12556.6
# Tributária                                           6892.05     7172.78
# ICMS                                                     NaN     5883.74
# IPVA                                                     NaN     314.724
# ITCD                                                     NaN     92.8002
# IRRF                                                     NaN     592.049
# Outras                                                   NaN     289.473
# Transferências                                       2331.64     2376.53
# FPE                                                      NaN     813.928
# Outras (inclusive Fundeb)                                NaN      1562.6
# Demais Correntes                                     1164.84     3007.24
# Receita de Capital                                   576.721     1947.62
# Despesa Total                                        11035.3     12444.9
# Despesa Corrente                                     9343.32     11953.3
# Pessoal e Encargos                                   5154.25     6825.06
# Ativos                                                   NaN     4860.34
# Inativos                                                 NaN     1964.72
# d/q Aposentadorias                                       NaN     1384.46
# d/q Reformas                                             NaN     275.567
# d/q Pensões                                              NaN     270.072
# d/q Demais                                               NaN       34.62
# Civil                                                    NaN     1632.61
# Militar                                                  NaN     315.734
# Outras Despesas Correntes                            3978.09     5128.27
# Transf. Constitucionais e Legais                      1946.7     1998.59
# Demais Despesas Correntes                             2031.4     3129.68
# Despesa de Capital                                      1692     491.596
# Investimentos                                        1647.53     491.596
# Inversões Financeiras                                44.4686  0.00013076
# Resultado Primário                                  -70.0784     2059.26
# Receita Corrente Própria/ Receita Bruta              73.4766     70.1869
# Receita de Transferências/ Receita Bruta             21.2639     16.3851
# Receita de Capital/ Receita Bruta                    5.25953      13.428
# Pessoal/ Despesa Total                               46.7069     54.8421
# Pessoal/ Despesa Total ex-Transf.                     56.711     65.3345
# Ativo/ Pessoal e Encargos                                  0     71.2131
# Inativo/ Pessoal e Encargos                                0     28.7869
# d/q Aposentadorias/ Inativos                               -     70.4661
# d/q Reformas/ Inativos                                     -     14.0257
# d/q Pensões/ Inativos                                      -     13.7461
# d/q Demais/ Inativos                                       -     1.76208
# Civil/ Inativos                                            -     83.0962
# Militar/ Inativos                                          -     16.0702
# Resultado Previdenciário (R$ milhões, a preços ...       NaN    -1127.01
# Déficit Previdenciário/ Rec. Corrente Própria              0    -11.0708
# Despesa de Capital/ Rec. Corrente Própria            21.0007     4.82902
# Resultado Primário/ Rec. Corrente Própria          -0.869794     20.2284
# estado                                                    MS          MS
#
#                                                           9        10       11
# Ano                                                     2016     2017  2018/08
# Receita Bruta                                        11530.5    12489  8106.19
# Receita Corrente                                     10925.4  11746.4  7619.28
# Tributária                                           5540.37  5983.91  4463.09
# ICMS                                                 4252.58  4521.58  3365.24
# IPVA                                                 197.766  201.409  216.808
# ITCD                                                 132.134  98.2015  87.9303
# IRRF                                                 676.262  887.255  613.073
# Outras                                               281.634   275.46  180.044
# Transferências                                        3052.6  3052.24  2107.37
# FPE                                                  967.197  913.633  658.571
# Outras (inclusive Fundeb)                            2085.41   2138.6   1448.8
# Demais Correntes                                     2332.45  2710.26  1048.82
# Receita de Capital                                   605.086  742.598  486.906
# Despesa Total                                        11456.5  12963.8  7307.35
# Despesa Corrente                                     10686.9  12000.8  6666.66
# Pessoal e Encargos                                   7532.81  8695.74  4904.59
# Ativos                                               5188.96  5868.75  3045.92
# Inativos                                             2343.85  2826.99  1858.67
# d/q Aposentadorias                                   1659.26  2028.18   1333.6
# d/q Reformas                                         309.312  392.298  263.033
# d/q Pensões                                           326.15  381.346  241.475
# d/q Demais                                           49.1271  25.1647  20.5638
# Civil                                                 1956.6  2366.68  1549.47
# Militar                                              355.202  450.128  299.189
# Outras Despesas Correntes                            3154.07  3305.07  1762.07
# Transf. Constitucionais e Legais                         175      171      112
# Demais Despesas Correntes                            2979.07  3134.07  1650.07
# Despesa de Capital                                   769.578  962.963  640.688
# Investimentos                                        762.618   962.96  640.688
# Inversões Financeiras                                   6.96  0.00276        0
# Resultado Primário                                   74.0498 -474.772  798.842
# Receita Corrente Própria/ Receita Bruta              68.2782  69.6146  67.9963
# Receita de Transferências/ Receita Bruta             26.4741  24.4394  25.9971
# Receita de Capital/ Receita Bruta                     5.2477  5.94602  6.00659
# Pessoal/ Despesa Total                               65.7516  67.0772  67.1187
# Pessoal/ Despesa Total ex-Transf.                    66.7716  67.9739  68.1634
# Ativo/ Pessoal e Encargos                            68.8848    67.49  62.1035
# Inativo/ Pessoal e Encargos                          31.1152    32.51  37.8965
# d/q Aposentadorias/ Inativos                          70.792  71.7435  71.7501
# d/q Reformas/ Inativos                               13.1968  13.8769  14.1517
# d/q Pensões/ Inativos                                13.9152  13.4895  12.9918
# d/q Demais/ Inativos                                   2.096  0.89016  1.10637
# Civil/ Inativos                                      83.4783  83.7173  83.3643
# Militar/ Inativos                                    15.1547  15.9225  16.0969
# Resultado Previdenciário (R$ milhões, a preços ...  -1171.35 -859.749 -424.867
# Déficit Previdenciário/ Rec. Corrente Própria       -14.8784  -9.8888 -7.70816
# Despesa de Capital/ Rec. Corrente Própria            9.77513   11.076  11.6237
# Resultado Primário/ Rec. Corrente Própria           0.940575 -5.46082   14.493
# estado                                                    MS       MS       MS

# %%
def get_financial_per_state_from_excel(excel):
    states=[sheet_name for sheet_name in excel.sheet_names if len(sheet_name)==2 ]
    df=None
    for state in states :
        df_aux=get_financials_of_state_from_excel(excel,state)
        if not (df is None):
            df=df.append(df_aux, ignore_index=True)
        else:
            df=df_aux
    return df


df=get_financial_per_state_from_excel(excel_file)
df.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-259-3416e7bfa959> in <module>
#      12
#      13 df=get_financial_per_state_from_excel(excel_file)
# ---> 14 df.plot()
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     716
#     717     def __call__(self, *args, **kwargs):
# --> 718         plot_backend = _get_plot_backend()
#     719
#     720         x, y, kind, kwargs = self._get_call_args(
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/site-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1550     if backend_str == "matplotlib":
#    1551         backend_str = "pandas.plotting._matplotlib"
# -> 1552     return importlib.import_module(backend_str)
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in <module>
#       1 from pandas._config import get_option
#       2
# ----> 3 from pandas.plotting._matplotlib.boxplot import (
#       4     BoxPlot,
#       5     boxplot,
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/site-packages/pandas/plotting/_matplotlib/boxplot.py in <module>
#       2 import warnings
#       3
# ----> 4 from matplotlib.artist import setp
#       5 import numpy as np
#       6
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# Out:
#            Ano  Receita Bruta  Receita Corrente    Tributária          ICMS  \
# count     11.0          11.00         11.000000     11.000000      4.000000
# unique    11.0          11.00         11.000000     11.000000      4.000000
# top     2015.0       39727.38      58046.798829  29071.688236  19327.754869
# freq       1.0           1.00          1.000000      1.000000      1.000000
#
#               IPVA       ITCD         IRRF       Outras  Transferências  ...  \
# count     4.000000    4.00000     4.000000     4.000000       11.000000  ...
# unique    4.000000    4.00000     4.000000     4.000000       11.000000  ...
# top     919.719162  959.64721  3831.315632  7118.637265     5743.360195  ...
# freq      1.000000    1.00000     1.000000     1.000000        1.000000  ...
#
#         d/q Aposentadorias/ Inativos  d/q Reformas/ Inativos  \
# count                             11                      11
# unique                             5                       5
# top                                -                       -
# freq                               7                       7
#
#         d/q Pensões/ Inativos  d/q Demais/ Inativos  Civil/ Inativos  \
# count                      11                    11               11
# unique                      5                     5                5
# top                         -                     -                -
# freq                        7                     7                7
#
#         Militar/ Inativos  \
# count                  11
# unique                  5
# top                     -
# freq                    7
#
#         Resultado Previdenciário (R$ milhões, a preços correntes)  \
# count                                            4.000000
# unique                                           4.000000
# top                                         -11345.982253
# freq                                             1.000000
#
#         Déficit Previdenciário/ Rec. Corrente Própria  \
# count                                            11.0
# unique                                            5.0
# top                                               0.0
# freq                                              7.0
#
#         Despesa de Capital/ Rec. Corrente Própria  \
# count                                   11.000000
# unique                                  11.000000
# top                                     14.646928
# freq                                     1.000000
#
#         Resultado Primário/ Rec. Corrente Própria
# count                                    11.00000
# unique                                   11.00000
# top                                     -17.95806
# freq                                      1.00000
#
# [4 rows x 49 columns]

# %%
df_RJ=df_RJ.drop(labels=[0])
df_RJ=df_RJ.drop(labels=[0])

df_RJ
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-302c80cd540b> in <module>
#       1 df_RJ.columns=df_RJ.iloc[0]
# ----> 2 df_RJ=df_RJ.drop(labels=[0], axis=0)
#       3 df_RJ
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4095             level=level,
#    4096             inplace=inplace,
# -> 4097             errors=errors,
#    4098         )
#    4099
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3913         for axis, labels in axes.items():
#    3914             if labels is not None:
# -> 3915                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3916
#    3917         if inplace:
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3945                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3946             else:
# -> 3947                 new_axis = axis.drop(labels, errors=errors)
#    3948             result = self.reindex(**{axis_name: new_axis})
#    3949
#
# ~/.local/share/virtualenvs/TutorialJupyter-vrelfNhQ/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5331         if mask.any():
#    5332             if errors != "ignore":
# -> 5333                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5334             indexer = indexer[~mask]
#    5335         return self.delete(indexer)
#
# KeyError: '[0] not found in axis'

# %%
a= None

# %%
# Out:
# caca
